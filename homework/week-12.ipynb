# %% [markdown]
# <a href="https://colab.research.google.com/github/HunterBlosser/ds1002-zpk9ym/blob/main/homework/week-12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Pie Chart (3 points)

# %%
# Create a pie chart from raw values

slices = [56, 66, 24, 124, 47]
labels = ["US","UK","MX","CA","JP"]

# %%
import matplotlib.pyplot as plt
plt.pie(slices, labels=labels, autopct='%1.1f%%', startangle=90)
# Out:
# ([<matplotlib.patches.Wedge at 0x7c2830e82770>,
#   <matplotlib.patches.Wedge at 0x7c2830e82680>,
#   <matplotlib.patches.Wedge at 0x7c2830e83460>,
#   <matplotlib.patches.Wedge at 0x7c2830e83af0>,
#   <matplotlib.patches.Wedge at 0x7c2830e1c1c0>],
#  [Text(-0.5796205069959816, 0.9349011005821533, 'US'),
#   Text(-1.079523234798625, -0.21125715497921713, 'UK'),
#   Text(-0.5134216160524556, -0.9728300181275683, 'MX'),
#   Text(0.9142379306117783, -0.6116935558191647, 'CA'),
#   Text(0.4940397524505564, 0.9828146941303804, 'JP')],
#  [Text(-0.3161566401796263, 0.5099460548629926, '17.7%'),
#   Text(-0.5888308553447045, -0.11523117544320932, '20.8%'),
#   Text(-0.28004815421043033, -0.53063455534231, '7.6%'),
#   Text(0.4986752348791517, -0.3336510304468171, '39.1%'),
#   Text(0.26947622860939435, 0.5360807422529347, '14.8%')])

# %% [markdown]
# ## Histogram (3 points)

# %%
# Create a histogram from random data

import matplotlib.pyplot as plt
import numpy as np

n = 430 + np.random.randn(3000)

# %%
plt.hist(n, bins=20)
# Out:
# (array([  4.,   8.,  14.,  47.,  85., 145., 227., 294., 358., 392., 369.,
#         350., 288., 180., 123.,  57.,  34.,  15.,   7.,   3.]),
#  array([426.69549071, 427.03024603, 427.36500134, 427.69975666,
#         428.03451197, 428.36926729, 428.7040226 , 429.03877792,
#         429.37353323, 429.70828855, 430.04304386, 430.37779918,
#         430.71255449, 431.04730981, 431.38206513, 431.71682044,
#         432.05157576, 432.38633107, 432.72108639, 433.0558417 ,
#         433.39059702]),
#  <BarContainer object of 20 artists>)

# %% [markdown]
# ## Scatterplot with Trendline (3 points)

# %%
# Create a scatterplot with a trendline from two lists of values

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

num_points = 50
x = 5 + np.arange(num_points) + np.random.randn(num_points)
y = 10 + np.arange(num_points) + 5 * np.random.randn(num_points)

# If you want them combined into a dataframe
df = pd.DataFrame({'x': x, 'y': y})

# %%
plt.scatter(x, y, label='Data Points')
coefficients = np.polyfit(x, y, 1)
trendline = np.polyval(coefficients, x)
plt.plot(x, trendline)
